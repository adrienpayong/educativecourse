# %% [markdown]
# <a href="https://colab.research.google.com/github/adrienpayong/educativecourse/blob/main/coharriscorner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

filename = 'test.jpg'
image = cv.imread(filename)
grayimage = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
grayimage = np.float32(grayimage)
dstimage = cv.cornerHarris(grayimage,2,3,0.04)
#result is dilated for the purpose of indicating the corners; this is unimportant. 
dstimage = cv.dilate(dstimage,None)
# The optimal value's threshold may change based on the image.
image[dstimage>0.01*dst.max()]=[0,0,255]
plt.imshow(image)
